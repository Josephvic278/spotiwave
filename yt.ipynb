# %%
import os, requests,re, httpx
headers = {
    'authority': 'www.net-a-porter.com',
    'accept': 'image/webp,image/apng,image/svg+xml,image/*,*/*;q=0.8',
    'accept-language': 'en-US,en;q=0.9',
    'cache-control': 'max-age=0',
    'cookie': 'PIM-SESSION-ID=Tq1MYBATOyJsZ5qN; _bamls_usid=65e5292e-fbef-4704-968c-0cf5b393c85a; TCPID=1231241742411825165294; TC_PRIVACY_CENTER=; LPVID=E0ZWUxYmYyYTVlYjYwOTNl; TC_PRIVACY=1^%^40006^%^7C48^%^7C5700^%^40^%^40^%^401703844548465^%^2C1703781761268^%^2C1737540548465^%^40; LPSID-73583570=kMa2OEo6SbiUrq7vxt8Vug; AKA_A2=A; _abck=EDCEC64B2318387EE9531496613E21BC~0~~-1~-1~1703848067',
    'dnt': '1',
    'if-modified-since': 'Fri, 15 Dec 2023 17:15:33 GMT',
    'sec-ch-ua': '^\\^Not_A',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'sec-fetch-dest': 'image',
    'sec-fetch-mode': 'no-cors',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-user': '?1',
    'sec-gpc': '1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36 Edg/120.0.0.0',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'DNT': '1',
    'Service-Worker-Navigation-Preload': 'true',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36 Edg/120.0.0.0',
    'referer': 'https://www.net-a-porter.com/variants/images/1647597321551574/in/w358_a3-4_q60.jpg',
}

import pickle
import secrets,selenium
import sys
import time
import undetected_chromedriver as uc
from selenium.webdriver import Chrome
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
import requests, time, random, os,json,csv, re
from bs4 import BeautifulSoup
import logging
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from glob import glob
logger = logging.getLogger('selenium')
logger.setLevel(logging.INFO)
# os.makedirs('Images/farfetch')
def get_options():
    options=uc.ChromeOptions()
    options.add_argument("--headless")

    options.add_argument("--no-sandbox")
    options.add_argument("--disable-dev-shm-usage")
    options.add_argument("--disable-notifications")
    options.add_argument("--disable-infobars")
    options.add_argument("--disable-extensions")
    options.add_argument("--window-size=1366,768")
    options.add_argument('--disable-blink-features=AutomationControlled')
    options.add_argument('--start-maximized')
    options.add_experimental_option("prefs", {
    
        "profile.default_content_setting_values.media_stream_mic": 1,
        "profile.default_content_setting_values.media_stream_camera": 1,
        "profile.default_content_setting_values.geolocation": 0,
        "profile.default_content_setting_values.notifications": 1
    })
    options.add_argument("--user-data-dir=C:/Users/Dunes/AppData/Local/Google/Chrome/User Data")
    return options

# %%
url = 'https://ytviews.webappbazaar.com'
driver = uc.Chrome(options=get_options())
# Out:
# could not detect version_main.therefore, we are assuming it is chrome 108 or higher

# %%
driver.save_screenshot('screenshot.png')
from IPython.display import Image
Image(filename='screenshot.png')

# %%
driver.save_screenshot('screenshot.png')
from IPython.display import Image
Image(filename='screenshot.png')

# %%
driver.get(url)

# %%
link_id='urlprathyousheo'
test_link = 'https://www.youtube.com/watch?v=uxolosbRTJo'

test_num = 5
num_id = 'nbrprathyousheo'

# %%
link_input = driver.find_element(By.ID,value=link_id)
link_input.click()
link_input.clear()
for i in test_link:
    link_input.send_keys(i)
    
num_input = driver.find_element(By.ID,value=num_id)
num_input.click()
num_input.clear()
num_input.send_keys(test_num)

# %%
buttons = driver.find_elements(By.TAG_NAME, value='button')
for button in buttons:
    if button.text == 'Play':
        button.click()
        break

# %%
videos_div = driver.find_elements(By.TAG_NAME, value='iframe')
for tag in videos_div:
    has_src = tag.get_attribute('src') != 'about:blank'
    if has_src:
        print(tag.get_attribute('src'))
        try:
            tag.click()
        except:
            pass
# Out:
# https://www.youtube.com/embed/uxolosbRTJo
# https://www.youtube.com/embed/uxolosbRTJo
# https://www.youtube.com/embed/uxolosbRTJo
# https://www.youtube.com/embed/uxolosbRTJo
# https://www.youtube.com/embed/uxolosbRTJo
